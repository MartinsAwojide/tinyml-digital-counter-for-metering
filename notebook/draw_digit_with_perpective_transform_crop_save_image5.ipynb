# %%
# directory = data5

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %%
ls data5
# Out:
# Img_10_473390839.bmp* Img_25_473391720.bmp* Img_3_473390428.bmp*
# Img_11_473390898.bmp* Img_26_473391779.bmp* Img_40_473392601.bmp*
# Img_12_473390957.bmp* Img_27_473391837.bmp* Img_41_473392659.bmp*
# Img_13_473391015.bmp* Img_28_473391896.bmp* Img_42_473392718.bmp*
# Img_14_473391074.bmp* Img_29_473391955.bmp* Img_43_473392777.bmp*
# Img_15_473391133.bmp* Img_2_473390370.bmp*  Img_44_473392836.bmp*
# Img_16_473391191.bmp* Img_30_473392014.bmp* Img_45_473392895.bmp*
# Img_17_473391250.bmp* Img_31_473392072.bmp* Img_46_473392953.bmp*
# Img_18_473391309.bmp* Img_32_473392131.bmp* Img_47_473393012.bmp*
# Img_19_473391368.bmp* Img_33_473392190.bmp* Img_48_473393071.bmp*
# Img_1_473390311.bmp*  Img_34_473392249.bmp* Img_4_473390487.bmp*
# Img_20_473391426.bmp* Img_35_473392307.bmp* Img_5_473390546.bmp*
# Img_21_473391485.bmp* Img_36_473392366.bmp* Img_6_473390604.bmp*
# Img_22_473391544.bmp* Img_37_473392425.bmp* Img_7_473390663.bmp*
# ...

# %%
image = cv2.imread('data5/Img_10_473390839.bmp', cv2.IMREAD_GRAYSCALE)

# %%
x1 = 87 
y1 = 87
x2 = 210
y2 = 87
x3 = 87 
y3 = 127
x4 = 210
y4 = 127
x = 15
y = 40
w = 20
h = 50
rect_w = 121
rect_h = 40
image = cv2.circle(image, (x1,y1), radius=1, color=(0, 0, 255), thickness=-1)
image = cv2.circle(image, (x2,y2), radius=1, color=(0, 0, 255), thickness=-1)
image = cv2.circle(image, (x3,y3), radius=1, color=(0, 0, 255), thickness=-1)
image = cv2.circle(image, (x4,y4), radius=1, color=(0, 0, 255), thickness=-1)
image = cv2.rectangle(image, (x1,y1),(x1+rect_w,y1+rect_h),(0,255,0), 1)
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Perpective Transformation

# %%
import cv2
from operator import itemgetter
from glob import glob
image = cv2.imread('Img_4_473386053.bmp', cv2.IMREAD_GRAYSCALE)
# Coordinates that you want to Perspective Transform
pts1 = np.float32([[87,87],[210,87],[87,127],[210,127]])
# Size of the Transformed Image
pts2 = np.float32([[0,0],[230,0],[0,80],[230,80]])
for val in pts1:
    cv2.circle(image,(val[0],val[1]),5,(0,255,0),-1)
M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(image,M,(230,80))
cv2.imwrite("transformed2.jpg", dst)
plt.imshow(dst)

# %%
image_transform = cv2.imread("data5/Img_10_473390839.bmp", cv2.IMREAD_GRAYSCALE)
digits = 3

for digit in range(digits):
    if digit >= 0: 
        initial_x = 47
        x = initial_x + digit*15 
        y = 15
        w = 15
        h = 25
        print(f"digit:{digit},x:{x},y:{y},w:{w},h:{h}")
        cropped = cv2.rectangle(image_transform,(x,y),(x+w,y+h),(0,255,0),1)
        plt.imshow(cropped)
        plt.show()
# Out:
# digit:0,x:47,y:15,w:15,h:25
# digit:1,x:62,y:15,w:15,h:25
# digit:2,x:77,y:15,w:15,h:25

# %%
image_transform.shape
# Out:
# (44, 123)

# %% [markdown]
# ## Account  for decimal point

# %%
image_transform = cv2.imread("data5/Img_10_473390839.bmp", cv2.IMREAD_GRAYSCALE)
plt.imshow(image_transform)
plt.show()

x_dp = 87
y_dp = 15
w_dp = 5
h_dp = 25
decimal_point = cv2.rectangle(image_transform,(x_dp,y_dp),(x_dp+w_dp,y_dp+h_dp),(0,255,0),1)
plt.imshow(decimal_point)
plt.show()

# %%
image_transform = cv2.imread("data5/Img_10_473390839.bmp", cv2.IMREAD_GRAYSCALE)
digits = 2

for digit in range(digits):
    if digit >= 0:
        initial_x = 47
        x = initial_x + digit*15 
        y = 15
        w = 15
        h = 25
        print(digit)
        cropped = cv2.rectangle(image_transform,(x,y),(x+w,y+h),(0,255,0),1)
        plt.imshow(cropped)
        plt.show()
# Out:
# 0
# 1

# %% [markdown]
# ## Combine before and after the decimal point

# %%
image_transform = cv2.imread("data5/Img_10_473390839.bmp", cv2.IMREAD_GRAYSCALE)
digits = 2

for digit in range(digits):
    if digit >= 0: 
        initial_x = 89
        x = initial_x + digit*15 
        y = 15
        w = 15
        h = 25
        print(f"digit:{digit},x:{x},y:{y},w:{w},h:{h}")
        cropped = cv2.rectangle(image_transform,(x,y),(x+w,y+h),(0,255,0),1)
        plt.imshow(cropped)
        plt.show()
# Out:
# digit:0,x:89,y:15,w:15,h:25
# digit:1,x:104,y:15,w:15,h:25

# %%
# !mkdir cropped2

# %%
image_transform = cv2.imread("data5/Img_10_473390839.bmp", cv2.IMREAD_GRAYSCALE)
digits_before = 4
digit_after = 2

# Before dp 
for digit in range(digits_before):
    if digit >= 0: 
        if digit == 3 or digit ==4: 
            continue 
        initial_x = 47
        x = initial_x + digit*15 
        y = 15
        w = 15
        h = 25
        print(digit)
        cropped = cv2.rectangle(image_transform,(x,y),(x+w,y+h),(0,255,0),1)
        plt.imshow(cropped)
        plt.show()

# After dp
for digit in range(digit_after):
    if digit >= 0:
        initial_x = 89
        x = initial_x + digit*15 
        y = 15
        w = 15
        h = 25
        print(digit)
        cropped = cv2.rectangle(image_transform,(x,y),(x+w,y+h),(0,255,0),1)
        plt.imshow(cropped)
        plt.show()
# Out:
# 0
# 1
# 2
# 0
# 1

# %%
# !ls cropped
# Out:
# 0.png  0_.png 1.png  1_.png 2.png

# %% [markdown]
# ## Crop and Save images

# %%
import os 
import uuid

# %%
path = "data5/"

for file in os.listdir(path): 
    gen = str(uuid.uuid4())
    print(file+gen)
# Out:
# Img_28_473391896.bmp25b24ba1-6464-4475-a26b-7935505cb6e5
# Img_1_473390311.bmpb756071d-5414-4c1b-ac15-091116160f86
# Img_4_473390487.bmp9baeccce-fc44-4643-88b5-ee0fafaba5ec
# Img_32_473392131.bmp97747bf1-fe08-4685-af1c-e26c8a25685c
# Img_34_473392249.bmp9f8a7798-089f-40a8-a3ee-42de33484486
# Img_42_473392718.bmp1297633a-a4ea-46ee-95ad-b952180f6b9f
# Img_48_473393071.bmpd8c651a9-5cc0-4b0d-869b-87ebf67e274c
# .DS_Store107ae8c4-a1ef-45a0-8896-ef67ab4572f1
# Img_20_473391426.bmp5fafc20d-756d-4012-943d-2f0affbe5f41
# Img_19_473391368.bmp5eb19de5-d2ee-4ba2-a0a5-07356dbe7313
# Img_17_473391250.bmpf8d3ffd0-b136-41f1-8bb3-3ab7135cafe0
# Img_9_473390780.bmp74b668cc-0436-47e7-a072-17824ba52721
# Img_6_473390604.bmp2ea67b61-974f-4904-82e0-adbc734faee9
# Img_40_473392601.bmpe8830557-540b-4718-a7f9-3a176081e031
# Img_44_473392836.bmp9647e27c-b459-45e9-aebd-56ce1831a8e1
# Img_38_473392483.bmp1b96da1f-312c-4b5e-8059-5916bfa3fe4b
# Img_30_473392014.bmp99a20785-0338-43ed-bdda-47ccdd1089f1
# ...

# %%
# Before
# !ls finished | wc -l
# Out:
#     2835

# %%
digits_before = 4
digit_after = 2

for file in os.listdir(path): 
    image_transform = cv2.imread("data5/" +file, cv2.IMREAD_GRAYSCALE)
    print(image_transform)

    # Before dp 
    for digit in range(digits_before):
        if digit >= 0: 
            if digit == 3 or digit ==4: 
                continue 
            initial_x = 47
            x = initial_x + digit*15 
            y = 15
            w = 15
            h = 25
            gen = str(uuid.uuid4())
            print(digit)
            print(file)
            cropped = image_transform
            cropped = cropped[y:y+h, x:x+w]
            cv2.imwrite(f'finished/{digit}_{gen}.png',cropped)
            plt.imshow(cropped)
            plt.show()

    # After dp
    for digit in range(digit_after):
        if digit >= 0:
            initial_x = 89
            x = initial_x + digit*15 
            y = 15
            w = 15
            h = 25
            gen = str(uuid.uuid4())
            print(digit)
            cropped = image_transform 
            cropped = cropped[y:y+h, x:x+w]
            cv2.imwrite(f'finished/{digit}_{gen}.png',cropped)
            plt.imshow(cropped)
            plt.show()
# Out:
# [[250 250 250 ... 250 250 250]
#  [250  60  49 ... 117 125 250]
#  [250  49  44 ...  76  84 250]
#  ...
#  [250  68  65 ...  68  76 250]
#  [250  89  88 ...  94 105 250]
#  [250 250 250 ... 250 250 250]]
# 0
# Img_28_473391896.bmp
# 1
# Img_28_473391896.bmp
# 2
# Img_28_473391896.bmp
# 0
# 1
# [[250 250 250 ... 250 250 250]
#  [250 110 102 ... 191 199 250]
#  [250 102  93 ... 140 145 250]
#  ...
#  [250 124 121 ... 125 135 250]
#  [250 152 149 ... 157 167 250]
#  [250 250 250 ... 250 250 250]]
# 0
# Img_1_473390311.bmp
# 1
# Img_1_473390311.bmp
# 2
# Img_1_473390311.bmp
# 0
# 1
# [[250 250 250 ... 250 250 250]
#  [250  94  84 ... 173 181 250]
#  [250  81  75 ... 120 122 250]
#  ...
#  [250  97  91 ... 106 114 250]
#  [250 123 122 ... 135 148 250]
#  [250 250 250 ... 250 250 250]]
# 0
# Img_4_473390487.bmp
# 1
# Img_4_473390487.bmp
# 2
# Img_4_473390487.bmp
# 0
# 1
# [[250 250 250 ... 250 250 250]
#  [250  47  41 ...  97 109 250]
#  [250  41  33 ...  61  68 250]
#  ...
# ...

# %%
# After
# !ls finished | wc -l
# Out:
#     3145
