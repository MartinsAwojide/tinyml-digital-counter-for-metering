# %% [markdown]
# ## Find rectangle

# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np 
gray = cv2.imread('Img_4_473386053.bmp', cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# # Draw rectangle

# %%
line_thickness = 1
w = 121
h = 39
x1_v = 87
y1_v = 87
x2_v = 87
y2_v = 87+h
x1_h = 87
y1_h = 87
x2_h = 87+120
y2_h = 87

#cv2.line(gray, (x1_v, y1_v), (x2_v, y2_v), (0, 255, 0), thickness=line_thickness)
#cv2.line(gray, (x1_h, y1_h), (x2_h, y2_h), (0, 255, 0), thickness=line_thickness)
cv2.rectangle(gray,(x1_v,y1_v),(x1_v+w,y1_v+h),(0,255,0),1)
plt.imshow(gray)
plt.show()
